# %% [markdown]
# GROUP Y - DATA SCIENCE PROJECT
# MALARIA IN AFRICA

# %%
#importing of necessary Libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#Control Display of seaborn data
pd.options.display.max_columns=50
sns.set(style="darkgrid", rc={"axes.facecolor":"#CAF1DE"})

# %% [markdown]
# READING THE DATASET AND EXPLORATION(BY ARUBE JOSHUA)

# %%
#Read the dataset
malaria_df = pd.read_csv(r'..\..\resources\datasets\MalariaAfricaDataset.csv')

#Load dataset
malaria_df
# Out:
#      Country Name  Year Country Code  \
# 0         Algeria  2007          DZA
# 1          Angola  2007          AGO
# 2           Benin  2007          BEN
# 3        Botswana  2007          BWA
# 4    Burkina Faso  2007          BFA
# ..            ...   ...          ...
# 589          Togo  2017          TGO
# 590       Tunisia  2017          TUN
# 591        Uganda  2017          UGA
# 592        Zambia  2017          ZMB
# 593      Zimbabwe  2017          ZWE
#
#      Incidence of malaria (per 1,000 population at risk)  \
# 0                                                 0.01
# 1                                               286.72
# 2                                               480.24
# 3                                                 1.03
# 4                                               503.80
# ..                                                 ...
# 589                                             278.20
# 590                                                NaN
# ...

# %%
#first 10 rows of the dataset
malaria_df.head(10)
# Out:
#                Country Name  Year Country Code  \
# 0                   Algeria  2007          DZA
# 1                    Angola  2007          AGO
# 2                     Benin  2007          BEN
# 3                  Botswana  2007          BWA
# 4              Burkina Faso  2007          BFA
# 5                   Burundi  2007          BDI
# 6                Cabo Verde  2007          CPV
# 7                  Cameroon  2007          CMR
# 8  Central African Republic  2007          CAF
# 9                      Chad  2007          TCD
#
#    Incidence of malaria (per 1,000 population at risk)  \
# 0                                               0.01
# 1                                             286.72
# 2                                             480.24
# 3                                               1.03
# 4                                             503.80
# 5                                             222.92
# 6                                               0.15
# ...

# %%
#last 10 rows of the dataset
malaria_df.tail(10)
# Out:
#      Country Name  Year Country Code  \
# 584       Somalia  2017          SOM
# 585  South Africa  2017          ZAF
# 586   South Sudan  2017          SSD
# 587         Sudan  2017          SDN
# 588      Tanzania  2017          TZA
# 589          Togo  2017          TGO
# 590       Tunisia  2017          TUN
# 591        Uganda  2017          UGA
# 592        Zambia  2017          ZMB
# 593      Zimbabwe  2017          ZWE
#
#      Incidence of malaria (per 1,000 population at risk)  \
# 584                                              37.13
# 585                                               3.95
# 586                                             245.80
# 587                                              46.75
# 588                                             123.96
# 589                                             278.20
# 590                                                NaN
# 591                                             336.76
# ...

# %%
#Get the number of rows and cloumns
malaria_df.shape
# Out:
# (594, 27)

# %%
#Check the datatypes
malaria_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 594 entries, 0 to 593
# Data columns (total 27 columns):
#  #   Column                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                   --------------  -----
#  0   Country Name                                                                             594 non-null    object
#  1   Year                                                                                     594 non-null    int64
#  2   Country Code                                                                             594 non-null    object
#  3   Incidence of malaria (per 1,000 population at risk)                                      550 non-null    float64
#  4   Malaria cases reported                                                                   550 non-null    float64
# ...

# %%
#Generate the descriptive statistics of the malaria dataframe and Tranpose it into a more readable form
malaria_df.describe().T
# Out:
#                                                     count          mean  \
# Year                                                594.0  2.012000e+03
# Incidence of malaria (per 1,000 population at r...  550.0  1.900875e+02
# Malaria cases reported                              550.0  1.068330e+06
# Use of insecticide-treated bed nets (% of under...  132.0  4.253030e+01
# Children with fever receiving antimalarial drug...  122.0  3.020164e+01
# Intermittent preventive treatment (IPT) of mala...  106.0  1.501396e+01
# People using safely managed drinking water serv...   99.0  3.347899e+01
# People using safely managed drinking water serv...   88.0  1.247057e+01
# People using safely managed drinking water serv...  176.0  5.154955e+01
# People using safely managed sanitation services...  132.0  2.876894e+01
# People using safely managed sanitation services...  110.0  1.436173e+01
# People using safely managed sanitation services...  132.0  3.217462e+01
# ...

# %%
#checking for nulls
malaria_df.isnull().sum().sort_values(ascending = False)
# Out:
# People using safely managed drinking water services, rural (% of rural population)         506
# People using safely managed drinking water services (% of population)                      495
# Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)      488
# People using safely managed sanitation services, rural (% of rural population)             484
# Children with fever receiving antimalarial drugs (% of children under age 5 with fever)    472
# People using safely managed sanitation services, urban  (% of urban population)            462
# People using safely managed sanitation services (% of population)                          462
# Use of insecticide-treated bed nets (% of under-5 population)                              462
# People using safely managed drinking water services, urban (% of urban population)         418
# Malaria cases reported                                                                      44
# ...

# %%
#check null in percentage
for i in malaria_df.columns:
    if malaria_df[i].isnull().any():
        print(i,  "-----------", malaria_df[i].isnull().sum()*100/malaria_df.shape[0],  "%")
# Out:
# Incidence of malaria (per 1,000 population at risk) ----------- 7.407407407407407 %
# Malaria cases reported ----------- 7.407407407407407 %
# Use of insecticide-treated bed nets (% of under-5 population) ----------- 77.77777777777777 %
# Children with fever receiving antimalarial drugs (% of children under age 5 with fever) ----------- 79.46127946127946 %
# Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women) ----------- 82.15488215488216 %
# People using safely managed drinking water services (% of population) ----------- 83.33333333333333 %
# People using safely managed drinking water services, rural (% of rural population) ----------- 85.18518518518519 %
# People using safely managed drinking water services, urban (% of urban population) ----------- 70.37037037037037 %
# People using safely managed sanitation services (% of population) ----------- 77.77777777777777 %
# ...

# %%
#checking null values in figure
import missingno as msno
msno.bar(malaria_df, color = "gray", fontsize = 21)
# Out:
# <Axes: >

# %%
#checking for duplicates
malaria_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# DATA PREPARATION AND CLEANING(BY LUBEMBE COLIN WAFULA)

# %%
# Handling the missing values
malaria_df.columns
# Out:
# Index(['Country Name', 'Year', 'Country Code',
#        'Incidence of malaria (per 1,000 population at risk)',
#        'Malaria cases reported',
#        'Use of insecticide-treated bed nets (% of under-5 population)',
#        'Children with fever receiving antimalarial drugs (% of children under age 5 with fever)',
#        'Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)',
#        'People using safely managed drinking water services (% of population)',
#        'People using safely managed drinking water services, rural (% of rural population)',
#        'People using safely managed drinking water services, urban (% of urban population)',
#        'People using safely managed sanitation services (% of population)',
#        'People using safely managed sanitation services, rural (% of rural population)',
#        'People using safely managed sanitation services, urban  (% of urban population)',
# ...

# %%
#filling the missing values in the columns with the mean
malaria_df['Rural population (% of total population)'].fillna(malaria_df['Rural population (% of total population)'].mean(), inplace=True)

malaria_df['Urban population (% of total population)'].fillna(malaria_df['Urban population (% of total population)'].mean(), inplace=True)

malaria_df['Rural population growth (annual %)'].fillna(malaria_df['Rural population growth (annual %)'].mean(), inplace=True)

malaria_df['Urban population growth (annual %)'].fillna(malaria_df['Urban population growth (annual %)'].mean(), inplace=True)

malaria_df['People using at least basic drinking water services (% of population)'].fillna(malaria_df['People using at least basic drinking water services (% of population)'].mean(), inplace=True)

malaria_df['People using at least basic drinking water services, rural (% of rural population)'].fillna(malaria_df['People using at least basic drinking water services, rural (% of rural population)'].mean(), inplace=True)

malaria_df['People using at least basic sanitation services, rural (% of rural population)'].fillna(malaria_df['People using at least basic sanitation services, rural (% of rural population)'].mean(), inplace=True)

malaria_df['People using at least basic sanitation services, urban  (% of urban population)'].fillna(malaria_df['People using at least basic sanitation services, urban  (% of urban population)'].mean(), inplace=True)

malaria_df['People using at least basic drinking water services, urban (% of urban population)'].fillna(malaria_df['People using at least basic drinking water services, urban (% of urban population)'].mean(), inplace=True)

malaria_df['People using at least basic sanitation services (% of population)'].fillna(malaria_df['People using at least basic sanitation services (% of population)'].mean(), inplace=True)

# %%
# replace the missing values in the columns with 0
malaria_df['Use of insecticide-treated bed nets (% of under-5 population)'].fillna(0, inplace=True)

malaria_df['Children with fever receiving antimalarial drugs (% of children under age 5 with fever)'].fillna(0, inplace=True)

malaria_df['Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)'].fillna(0, inplace=True)

malaria_df['People using safely managed drinking water services (% of population)'].fillna(0, inplace=True)

malaria_df['People using safely managed drinking water services, rural (% of rural population)'].fillna(0, inplace=True)

malaria_df['People using safely managed drinking water services, urban (% of urban population)'].fillna(0, inplace=True)

malaria_df['People using safely managed sanitation services (% of population)'].fillna(0, inplace=True)

malaria_df['People using safely managed sanitation services, rural (% of rural population)'].fillna(0, inplace=True)

malaria_df['People using safely managed sanitation services, urban  (% of urban population)'].fillna(0, inplace=True)

malaria_df['Incidence of malaria (per 1,000 population at risk)'].fillna(0, inplace=True)

malaria_df['Malaria cases reported'].fillna(0, inplace=True)

# %%
#checking for nulls
malaria_df.isnull().sum().sort_values(ascending = False)
# Out:
# Country Name                                                                               0
# Rural population (% of total population)                                                   0
# longitude                                                                                  0
# latitude                                                                                   0
# People using at least basic sanitation services, urban  (% of urban population)            0
# People using at least basic sanitation services, rural (% of rural population)             0
# People using at least basic sanitation services (% of population)                          0
# People using at least basic drinking water services, urban (% of urban population)         0
# People using at least basic drinking water services, rural (% of rural population)         0
# People using at least basic drinking water services (% of population)                      0
# ...

# %%
#check unique values using for loop
for i in malaria_df.columns:
    print(i,  "-----------", malaria_df[i].nunique())
# Out:
# Country Name ----------- 54
# Year ----------- 11
# Country Code ----------- 54
# Incidence of malaria (per 1,000 population at risk) ----------- 499
# Malaria cases reported ----------- 467
# Use of insecticide-treated bed nets (% of under-5 population) ----------- 118
# Children with fever receiving antimalarial drugs (% of children under age 5 with fever) ----------- 111
# Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women) ----------- 95
# People using safely managed drinking water services (% of population) ----------- 100
# People using safely managed drinking water services, rural (% of rural population) ----------- 88
# People using safely managed drinking water services, urban (% of urban population) ----------- 172
# People using safely managed sanitation services (% of population) ----------- 131
# People using safely managed sanitation services, rural (% of rural population) ----------- 109
# ...

# %%
# splitting the dataset into training and test sets
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(malaria_df, test_size=0.2, random_state=42)

# %%
#checking the shape of the train and test sets
print(train_set.shape)
print(test_set.shape)
# Out:
# (475, 27)
# (119, 27)

# %%
#Loading dataset after cleaning
malaria_df
# Out:
#      Country Name  Year Country Code  \
# 0         Algeria  2007          DZA
# 1          Angola  2007          AGO
# 2           Benin  2007          BEN
# 3        Botswana  2007          BWA
# 4    Burkina Faso  2007          BFA
# ..            ...   ...          ...
# 589          Togo  2017          TGO
# 590       Tunisia  2017          TUN
# 591        Uganda  2017          UGA
# 592        Zambia  2017          ZMB
# 593      Zimbabwe  2017          ZWE
#
#      Incidence of malaria (per 1,000 population at risk)  \
# 0                                                 0.01
# 1                                               286.72
# 2                                               480.24
# 3                                                 1.03
# 4                                               503.80
# ..                                                 ...
# 589                                             278.20
# 590                                               0.00
# ...

# %% [markdown]
# DATA VISUALIZATION(BY KATO TREVOR THOMAS AND NANSUMBA MARY VANESSA)
